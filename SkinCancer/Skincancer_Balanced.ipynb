# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow==2.9

# %%
# !unzip "/content/drive/MyDrive/Phase II Project Work.zip"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dropout,Flatten,Dense,BatchNormalization,GlobalAvgPool2D,GaussianNoise,GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# import tensorflow as tf
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=3072)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# import tensorflow as tf
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
test_set="/content/Phase II Project Work/Cancer_Data_Set/Skin_Cancer_Balanced/test"
train_set="/content/Phase II Project Work/Cancer_Data_Set/Skin_Cancer_Balanced/train"

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_datagen= ImageDataGenerator(    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size = (224,224),
    batch_size = 8,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_set,
    target_size = (224,224),
    batch_size = 8,
    shuffle=True,
    class_mode = 'categorical')
# Out:
# Found 9000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
train_generator

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
es= EarlyStopping(monitor="accuracy",min_delta=0.01,patience=8,verbose=1,mode='auto')
mc=ModelCheckpoint(monitor="accuracy",filepath="/content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5",verbose=1,save_best_only=True,mode='auto')
cd=[es,mc]

# %%
import tensorflow as tf
base_model = tf.keras.applications.EfficientNetB2(weights='imagenet', input_shape=(224,224,3), include_top=False)
# base_model = tf.keras.applications.resnet50.ResNet50(weights='imagenet', input_shape=(224,224,3), include_top=False)
model = Sequential()
model.add(base_model)
model.add(GaussianNoise(0.25))
model.add(GlobalAveragePooling2D())
model.add(Dense(256,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.25))
model.add(Dropout(0.25))
model.add(Dense(2, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 7, 7, 1408)       7768569
#
#  gaussian_noise (GaussianNoi  (None, 7, 7, 1408)       0
#  se)
#
#  global_average_pooling2d (G  (None, 1408)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               360704
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  gaussian_noise_1 (GaussianN  (None, 256)              0
#  oise)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 8,130,811
# Trainable params: 8,062,724
# Non-trainable params: 68,087
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy','Precision','Recall'])

# %%
hs=model.fit(
    train_generator,
    epochs=20,
    batch_size=64,
    verbose=1,
    validation_data=test_generator,
    callbacks=cd
    )
# Out:
# Epoch 1/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.4805 - accuracy: 0.8091 - precision: 0.8091 - recall: 0.8091
# Epoch 1: accuracy improved from -inf to 0.80911, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 260s 213ms/step - loss: 0.4805 - accuracy: 0.8091 - precision: 0.8091 - recall: 0.8091 - val_loss: 0.3363 - val_accuracy: 0.8760 - val_precision: 0.8760 - val_recall: 0.8760
# Epoch 2/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.3939 - accuracy: 0.8357 - precision: 0.8357 - recall: 0.8357
# Epoch 2: accuracy improved from 0.80911 to 0.83567, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 237s 211ms/step - loss: 0.3939 - accuracy: 0.8357 - precision: 0.8357 - recall: 0.8357 - val_loss: 1.4208 - val_accuracy: 0.7930 - val_precision: 0.7930 - val_recall: 0.7930
# Epoch 3/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.3432 - accuracy: 0.8671 - precision: 0.8671 - recall: 0.8671
# Epoch 3: accuracy improved from 0.83567 to 0.86711, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 237s 210ms/step - loss: 0.3432 - accuracy: 0.8671 - precision: 0.8671 - recall: 0.8671 - val_loss: 0.2805 - val_accuracy: 0.8920 - val_precision: 0.8920 - val_recall: 0.8920
# Epoch 4/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.3297 - accuracy: 0.8704 - precision: 0.8704 - recall: 0.8704
# Epoch 4: accuracy improved from 0.86711 to 0.87044, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 236s 210ms/step - loss: 0.3297 - accuracy: 0.8704 - precision: 0.8704 - recall: 0.8704 - val_loss: 0.3400 - val_accuracy: 0.8660 - val_precision: 0.8660 - val_recall: 0.8660
# Epoch 5/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.3073 - accuracy: 0.8861 - precision: 0.8861 - recall: 0.8861
# Epoch 5: accuracy improved from 0.87044 to 0.88611, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 239s 212ms/step - loss: 0.3073 - accuracy: 0.8861 - precision: 0.8861 - recall: 0.8861 - val_loss: 16.1579 - val_accuracy: 0.7710 - val_precision: 0.7710 - val_recall: 0.7710
# Epoch 6/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.8952 - precision: 0.8952 - recall: 0.8952
# Epoch 6: accuracy improved from 0.88611 to 0.89522, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 240s 213ms/step - loss: 0.2905 - accuracy: 0.8952 - precision: 0.8952 - recall: 0.8952 - val_loss: 0.2903 - val_accuracy: 0.8990 - val_precision: 0.8990 - val_recall: 0.8990
# Epoch 7/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.8901 - precision: 0.8901 - recall: 0.8901
# Epoch 7: accuracy did not improve from 0.89522
# 1125/1125 [==============================] - 241s 214ms/step - loss: 0.2921 - accuracy: 0.8901 - precision: 0.8901 - recall: 0.8901 - val_loss: 93.4194 - val_accuracy: 0.7340 - val_precision: 0.7340 - val_recall: 0.7340
# Epoch 8/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.8947 - precision: 0.8947 - recall: 0.8947
# Epoch 8: accuracy did not improve from 0.89522
# 1125/1125 [==============================] - 237s 210ms/step - loss: 0.2896 - accuracy: 0.8947 - precision: 0.8947 - recall: 0.8947 - val_loss: 0.2950 - val_accuracy: 0.8980 - val_precision: 0.8980 - val_recall: 0.8980
# Epoch 9/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2836 - accuracy: 0.8949 - precision: 0.8949 - recall: 0.8949
# Epoch 9: accuracy did not improve from 0.89522
# 1125/1125 [==============================] - 230s 204ms/step - loss: 0.2836 - accuracy: 0.8949 - precision: 0.8949 - recall: 0.8949 - val_loss: 3.8064 - val_accuracy: 0.8140 - val_precision: 0.8140 - val_recall: 0.8140
# Epoch 10/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2671 - accuracy: 0.9040 - precision: 0.9040 - recall: 0.9040
# Epoch 10: accuracy improved from 0.89522 to 0.90400, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 231s 205ms/step - loss: 0.2671 - accuracy: 0.9040 - precision: 0.9040 - recall: 0.9040 - val_loss: 0.2266 - val_accuracy: 0.9100 - val_precision: 0.9100 - val_recall: 0.9100
# Epoch 11/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.9029 - precision: 0.9029 - recall: 0.9029
# Epoch 11: accuracy did not improve from 0.90400
# 1125/1125 [==============================] - 234s 208ms/step - loss: 0.2760 - accuracy: 0.9029 - precision: 0.9029 - recall: 0.9029 - val_loss: 0.2372 - val_accuracy: 0.9010 - val_precision: 0.9010 - val_recall: 0.9010
# Epoch 12/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.9052 - precision: 0.9052 - recall: 0.9052
# Epoch 12: accuracy improved from 0.90400 to 0.90522, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 232s 206ms/step - loss: 0.2687 - accuracy: 0.9052 - precision: 0.9052 - recall: 0.9052 - val_loss: 0.2639 - val_accuracy: 0.9110 - val_precision: 0.9110 - val_recall: 0.9110
# Epoch 13/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2583 - accuracy: 0.9126 - precision: 0.9126 - recall: 0.9126
# Epoch 13: accuracy improved from 0.90522 to 0.91256, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 229s 203ms/step - loss: 0.2583 - accuracy: 0.9126 - precision: 0.9126 - recall: 0.9126 - val_loss: 0.2710 - val_accuracy: 0.9080 - val_precision: 0.9080 - val_recall: 0.9080
# Epoch 14/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2567 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058
# Epoch 14: accuracy did not improve from 0.91256
# 1125/1125 [==============================] - 226s 201ms/step - loss: 0.2567 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - val_loss: 0.2538 - val_accuracy: 0.8960 - val_precision: 0.8960 - val_recall: 0.8960
# Epoch 15/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2631 - accuracy: 0.9091 - precision: 0.9091 - recall: 0.9091
# Epoch 15: accuracy did not improve from 0.91256
# 1125/1125 [==============================] - 225s 200ms/step - loss: 0.2631 - accuracy: 0.9091 - precision: 0.9091 - recall: 0.9091 - val_loss: 0.2579 - val_accuracy: 0.9020 - val_precision: 0.9020 - val_recall: 0.9020
# Epoch 16/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9093 - precision: 0.9093 - recall: 0.9093
# Epoch 16: accuracy did not improve from 0.91256
# 1125/1125 [==============================] - 227s 201ms/step - loss: 0.2547 - accuracy: 0.9093 - precision: 0.9093 - recall: 0.9093 - val_loss: 0.2766 - val_accuracy: 0.8970 - val_precision: 0.8970 - val_recall: 0.8970
# Epoch 17/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152
# Epoch 17: accuracy improved from 0.91256 to 0.91522, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 231s 205ms/step - loss: 0.2428 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - val_loss: 0.2287 - val_accuracy: 0.9140 - val_precision: 0.9140 - val_recall: 0.9140
# Epoch 18/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.9172 - precision: 0.9172 - recall: 0.9172
# Epoch 18: accuracy improved from 0.91522 to 0.91722, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinbalanced.h5
# 1125/1125 [==============================] - 230s 204ms/step - loss: 0.2356 - accuracy: 0.9172 - precision: 0.9172 - recall: 0.9172 - val_loss: 0.2383 - val_accuracy: 0.8900 - val_precision: 0.8900 - val_recall: 0.8900
# Epoch 19/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2525 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160
# Epoch 19: accuracy did not improve from 0.91722
# 1125/1125 [==============================] - 231s 205ms/step - loss: 0.2525 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - val_loss: 0.2418 - val_accuracy: 0.9000 - val_precision: 0.9000 - val_recall: 0.9000
# Epoch 20/20
# 1125/1125 [==============================] - ETA: 0s - loss: 0.2539 - accuracy: 0.9130 - precision: 0.9130 - recall: 0.9130
# Epoch 20: accuracy did not improve from 0.91722
# 1125/1125 [==============================] - 231s 205ms/step - loss: 0.2539 - accuracy: 0.9130 - precision: 0.9130 - recall: 0.9130 - val_loss: 0.2541 - val_accuracy: 0.9050 - val_precision: 0.9050 - val_recall: 0.9050

# %%
from matplotlib import pyplot as plt
plt.plot(hs.history['accuracy'])
plt.plot(hs.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
