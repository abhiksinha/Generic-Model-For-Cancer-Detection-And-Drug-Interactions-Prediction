# %%
# !pip install tensorflow==2.9

# %%
# !unzip "/content/drive/MyDrive/Phase II Project Work.zip"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dropout,Flatten,Dense,BatchNormalization,GlobalAvgPool2D,GaussianNoise,GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# import tensorflow as tf
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=3072)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import tensorflow as tf
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# import tensorflow as tf
# gpus = tf.config.experimental.list_physical_devices('GPU')
# for gpu in gpus:
#   tf.config.experimental.set_memory_growth(gpu, True)

# %%
# from tensorflow.compat.v1 import ConfigProto
# from tensorflow.compat.v1 import InteractiveSession
# config = ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.7
# session = InteractiveSession(config=config)

# %%
test_set="/content/Phase II Project Work/Cancer_Data_Set/Skin_Cancer/test"
train_set="/content/Phase II Project Work/Cancer_Data_Set/Skin_Cancer/train"

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_datagen= ImageDataGenerator(    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size = (224,224),
    batch_size = 8,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_set,
    target_size = (224,224),
    batch_size = 8,
    shuffle=True,
    class_mode = 'categorical')
# Out:
# Found 6000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
train_generator

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
es= EarlyStopping(monitor="accuracy",min_delta=0.01,patience=6,verbose=1,mode='auto')
mc=ModelCheckpoint(monitor="accuracy",filepath="/content/drive/MyDrive/Phase II Project Work/SkinCancer/skinmodel.h5",verbose=1,save_best_only=True,mode='auto')
cd=[es,mc]

# %%
import tensorflow as tf
base_model = tf.keras.applications.EfficientNetB2(weights='imagenet', input_shape=(224,224,3), include_top=False)
# base_model = tf.keras.applications.resnet50.ResNet50(weights='imagenet', input_shape=(224,224,3), include_top=False)
model = Sequential()
model.add(base_model)
model.add(GaussianNoise(0.25))
model.add(GlobalAveragePooling2D())
model.add(Dense(256,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.25))
model.add(Dropout(0.25))
model.add(Dense(2, activation='softmax'))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 7, 7, 1408)       7768569
#
#  gaussian_noise (GaussianNoi  (None, 7, 7, 1408)       0
#  se)
#
#  global_average_pooling2d (G  (None, 1408)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               360704
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  gaussian_noise_1 (GaussianN  (None, 256)              0
#  oise)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 8,130,811
# Trainable params: 8,062,724
# Non-trainable params: 68,087
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy','Precision','Recall'])

# %%
hs=model.fit(
    train_generator,
    epochs=20,
    steps_per_epoch=70,
    verbose=1,
    validation_data=test_generator,
    callbacks=cd
    )
# Out:
# Epoch 1/20
# 70/70 [==============================] - ETA: 0s - loss: 0.8592 - accuracy: 0.7750 - precision: 0.7750 - recall: 0.7750
# Epoch 1: accuracy improved from -inf to 0.77500, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinmodel.h5
# 70/70 [==============================] - 57s 455ms/step - loss: 0.8592 - accuracy: 0.7750 - precision: 0.7750 - recall: 0.7750 - val_loss: 0.6448 - val_accuracy: 0.6700 - val_precision: 0.6700 - val_recall: 0.6700
# Epoch 2/20
# 70/70 [==============================] - ETA: 0s - loss: 0.4875 - accuracy: 0.8089 - precision: 0.8089 - recall: 0.8089
# Epoch 2: accuracy improved from 0.77500 to 0.80893, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/sk
20
# 70/70 [==============================] - ETA: 0s - loss: 0.3096 - accuracy: 0.8696 - precision: 0.8696 - recall: 0.8696
# Epoch 12: accuracy improved from 0.86429 to 0.86964, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinmodel.h5
# 70/70 [==============================] - 31s 441ms/step - loss: 0.3096 - accuracy: 0.8696 - precision: 0.8696 - recall: 0.8696 - val_loss: 0.3175 - val_accuracy: 0.9020 - val_precision: 0.9020 - val_recall: 0.9020
# Epoch 13/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.8536 - precision: 0.8536 - recall: 0.8536
# Epoch 13: accuracy did not improve from 0.86964
# 70/70 [==============================] - 27s 384ms/step - loss: 0.3854 - accuracy: 0.8536 - precision: 0.8536 - recall: 0.8536 - val_loss: 0.4492 - val_accuracy: 0.7970 - val_precision: 0.7970 - val_recall: 0.7970
# Epoch 14/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3213 - accuracy: 0.8821 - precision: 0.8821 - recall: 0.8821
# Epoch 14: accuracy improved from 0.86964 to 0.88214, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinmodel.h5
# 70/70 [==============================] - 30s 424ms/step - loss: 0.3213 - accuracy: 0.8821 - precision: 0.8821 - recall: 0.8821 - val_loss: 0.3526 - val_accuracy: 0.8680 - val_precision: 0.8680 - val_recall: 0.8680
# Epoch 15/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.8589 - precision: 0.8589 - recall: 0.8589
# Epoch 15: accuracy did not improve from 0.88214
# 70/70 [==============================] - 28s 408ms/step - loss: 0.3559 - accuracy: 0.8589 - precision: 0.8589 - recall: 0.8589 - val_loss: 0.3613 - val_accuracy: 0.8690 - val_precision: 0.8690 - val_recall: 0.8690
# Epoch 16/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8875 - precision: 0.8875 - recall: 0.8875
# Epoch 16: accuracy improved from 0.88214 to 0.88750, saving model to /content/drive/MyDrive/Phase II Project Work/SkinCancer/skinmodel.h5
# 70/70 [==============================] - 28s 404ms/step - loss: 0.3463 - accuracy: 0.8875 - precision: 0.8875 - recall: 0.8875 - val_loss: 0.5326 - val_accuracy: 0.8510 - val_precision: 0.8510 - val_recall: 0.8510
# Epoch 17/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3427 - accuracy: 0.8589 - precision: 0.8589 - recall: 0.8589
# Epoch 17: accuracy did not improve from 0.88750
# 70/70 [==============================] - 28s 402ms/step - loss: 0.3427 - accuracy: 0.8589 - precision: 0.8589 - recall: 0.8589 - val_loss: 0.3319 - val_accuracy: 0.8730 - val_precision: 0.8730 - val_recall: 0.8730
# Epoch 18/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3268 - accuracy: 0.8696 - precision: 0.8696 - recall: 0.8696
# Epoch 18: accuracy did not improve from 0.88750
# 70/70 [==============================] - 27s 381ms/step - loss: 0.3268 - accuracy: 0.8696 - precision: 0.8696 - recall: 0.8696 - val_loss: 0.5142 - val_accuracy: 0.7910 - val_precision: 0.7910 - val_recall: 0.7910
# Epoch 19/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.8768 - precision: 0.8768 - recall: 0.8768
# Epoch 19: accuracy did not improve from 0.88750
# 70/70 [==============================] - 27s 385ms/step - loss: 0.3113 - accuracy: 0.8768 - precision: 0.8768 - recall: 0.8768 - val_loss: 0.2749 - val_accuracy: 0.8930 - val_precision: 0.8930 - val_recall: 0.8930
# Epoch 20/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3204 - accuracy: 0.8571 - precision: 0.8571 - recall: 0.8571
# Epoch 20: accuracy did not improve from 0.88750
# 70/70 [==============================] - 27s 394ms/step - loss: 0.3204 - accuracy: 0.8571 - precision: 0.8571 - recall: 0.8571 - val_loss: 0.2846 - val_accuracy: 0.8980 - val_precision: 0.8980 - val_recall: 0.8980
# Epoch 20: early stopping

# %%
from matplotlib import pyplot as plt
plt.plot(hs.history['accuracy'])
plt.plot(hs.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
