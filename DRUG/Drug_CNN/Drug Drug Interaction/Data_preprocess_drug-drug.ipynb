# %%
import pandas as pd

# %%
paths="D:\Phase II Project Work\DRUG\Drug_CNN\DDI\Data\\"

# %%
df1=pd.read_csv(paths+"Drugbank.csv")
df1=df1[['name','drugbank_id']]
df1.head()
# Out:
#            name drugbank_id
# 0   Bivalirudin     DB00006
# 1     Goserelin     DB00014
# 2  Desmopressin     DB00035
# 3    Cetrorelix     DB00050
# 4  Cyclosporine     DB00091

# %%
df2=pd.read_csv(paths+"cancer_drugs.csv")

# %%
df_final=pd.merge(df1,df2,on='name')

# %%
df_final.count()
# Out:
# name           88
# drugbank_id    88
# dtype: int64

# %%
df_final=df_final.drop_duplicates()

# %%
df_final.count()
# Out:
# name           64
# drugbank_id    64
# dtype: int64

# %%
df_final.head()
# Out:
#            name drugbank_id
# 0    Bortezomib     DB00188
# 1    Cladribine     DB00242
# 3    Carmustine     DB00262
# 6  Chlorambucil     DB00291
# 8     Gefitinib     DB00317

# %%
df_final
# Out:
#             name drugbank_id
# 0     Bortezomib     DB00188
# 1     Cladribine     DB00242
# 3     Carmustine     DB00262
# 6   Chlorambucil     DB00291
# 8      Gefitinib     DB00317
# ..           ...         ...
# 82     Bosutinib     DB06616
# 83     Degarelix     DB06699
# 84  Bendamustine     DB06769
# 85   Cabazitaxel     DB06772
# 86  Pralatrexate     DB06813
#
# [64 rows x 2 columns]

# %%
df_inter=pd.read_csv(paths+"drug_drug.tsv",sep='\t')

# %%
df_inter.head(10)
# Out:
#         l1       l2
# 0  DB00862  DB00966
# 1  DB00575  DB00806
# 2  DB01242  DB08893
# 3  DB01151  DB08883
# 4  DB01235  DB01275
# 5  DB00018  DB00333
# 6  DB00201  DB01609
# 7  DB00712  DB01418
# 8  DB01576  DB04842
# 9  DB01609  DB06212

# %%
df_inter.count()
# Out:
# l1    48514
# l2    48514
# dtype: int64

# %%
# bortezomib
v=[]
cnt=0
obj={}
#oversampling
sampling_factor=3
for l1,l2 in zip(df_inter['l1'],df_inter['l2']):
    if(l1=="DB00188"):
        for i in range(sampling_factor):
            v.append([l2,1])
        obj[l2]=1
    
for x in df1['drugbank_id']:
    if(x not in obj):
        v.append([x,0])
        cnt+=1;
    if(cnt==500):
        break;

# %%
df_borte=pd.DataFrame(v,columns=['drugbank_id','interact'])
df_borte.head(10)
# Out:
#   drugbank_id  interact
# 0     DB09118         1
# 1     DB09118         1
# 2     DB09118         1
# 3     DB00736         1
# 4     DB00736         1
# 5     DB00736         1
# 6     DB01087         1
# 7     DB01087         1
# 8     DB01087         1
# 9     DB08880         1

# %%
df_borte_final=pd.merge(df1,df_borte,on='drugbank_id')
df_borte_final
# Out:
#              name drugbank_id  interact
# 0     Bivalirudin     DB00006         0
# 1       Goserelin     DB00014         0
# 2    Desmopressin     DB00035         0
# 3      Cetrorelix     DB00050         0
# 4    Cyclosporine     DB00091         0
# ..            ...         ...       ...
# 699   Armodafinil     DB06413         1
# 700   Armodafinil     DB06413         1
# 701    Etravirine     DB06414         1
# 702    Etravirine     DB06414         1
# 703    Etravirine     DB06414         1
#
# [704 rows x 3 columns]

# %%
data_smiles=pd.read_csv(paths+"Drugbank.csv")
data_smiles=data_smiles[['drugbank_id','smiles']]
data_smiles=data_smiles.drop_duplicates()

# %%
data_smiles.head()
# Out:
#   drugbank_id                                             smiles
# 0     DB00006  CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
# 1     DB00014  CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 2     DB00035  NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...
# 3     DB00050  CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H...
# 4     DB00091  CCC1NC(=O)C(C(O)C(C)C\C=C\C)N(C)C(=O)C(C(C)C)N...

# %%
df_borte_smiles=pd.merge(df_borte_final,data_smiles,on='drugbank_id')

# %%
df_borte_smiles
# Out:
#              name drugbank_id  interact  \
# 0     Bivalirudin     DB00006         0
# 1       Goserelin     DB00014         0
# 2    Desmopressin     DB00035         0
# 3      Cetrorelix     DB00050         0
# 4    Cyclosporine     DB00091         0
# ..            ...         ...       ...
# 699   Armodafinil     DB06413         1
# 700   Armodafinil     DB06413         1
# 701    Etravirine     DB06414         1
# 702    Etravirine     DB06414         1
# 703    Etravirine     DB06414         1
#
#                                                 smiles
# 0    CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
# 1    CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 2    NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...
# 3    CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H...
# 4    CCC1NC(=O)C(C(O)C(C)C\C=C\C)N(C)C(=O)C(C(C)C)N...
# ..                                                 ...
# 699          NC(=O)C[S@@](=O)C(C1=CC=CC=C1)C1=CC=CC=C1
# ...

# %%
df_ttt=df_borte_smiles.drop_duplicates()
df_ttt
# Out:
#              name drugbank_id  interact  \
# 0     Bivalirudin     DB00006         0
# 1       Goserelin     DB00014         0
# 2    Desmopressin     DB00035         0
# 3      Cetrorelix     DB00050         0
# 4    Cyclosporine     DB00091         0
# ..            ...         ...       ...
# 689  Methsuximide     DB05246         1
# 692    Telaprevir     DB05521         1
# 695   Abiraterone     DB05812         1
# 698   Armodafinil     DB06413         1
# 701    Etravirine     DB06414         1
#
#                                                 smiles
# 0    CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...
# 1    CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...
# 2    NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...
# 3    CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H...
# 4    CCC1NC(=O)C(C(O)C(C)C\C=C\C)N(C)C(=O)C(C(C)C)N...
# ..                                                 ...
# 689                     CN1C(=O)CC(C)(C1=O)C1=CC=CC=C1
# ...

# %%
df_ttt[['smiles','interact']]
# Out:
#                                                 smiles  interact
# 0    CC[C@H](C)[C@H](NC(=O)[C@H](CCC(O)=O)NC(=O)[C@...         0
# 1    CC(C)C[C@H](NC(=O)[C@@H](COC(C)(C)C)NC(=O)[C@H...         0
# 2    NC(=O)CC[C@@H]1NC(=O)[C@H](CC2=CC=CC=C2)NC(=O)...         0
# 3    CC(C)C[C@H](NC(=O)[C@@H](CCCNC(N)=O)NC(=O)[C@H...         0
# 4    CCC1NC(=O)C(C(O)C(C)C\C=C\C)N(C)C(=O)C(C(C)C)N...         0
# ..                                                 ...       ...
# 689                     CN1C(=O)CC(C)(C1=O)C1=CC=CC=C1         1
# 692  [H][C@@]12CCC[C@]1([H])[C@H](N(C2)C(=O)[C@@H](...         1
# 695  [H][C@@]12CC=C(C3=CC=CN=C3)[C@@]1(C)CC[C@@]1([...         1
# 698          NC(=O)C[S@@](=O)C(C1=CC=CC=C1)C1=CC=CC=C1         1
# 701  CC1=CC(=CC(C)=C1OC1=C(Br)C(N)=NC(NC2=CC=C(C=C2...         1
#
# [568 rows x 2 columns]

# %%
df_to_write=df_borte_smiles[['smiles','interact']]
df_to_write.to_csv(paths+"Bortezomib_interaction.csv",index=False)

# %%
import pandas as pd
borte_d=pd.read_csv(paths+"bortezo.tsv", sep='\t')
borte_d=borte_d[['name']]
borte_d.head()
# Out:
#           name
# 0   Abametapir
# 1    Abatacept
# 2    Abciximab
# 3  Abemaciclib
# 4  Abiraterone

# %%
df_db=pd.read_csv(paths+"Drugbank.csv")
df_db=df_db[['name','smiles']]

# %%
df_merge_db= pd.merge(borte_d,df_db,on='name')
df_merge_db.head()
# Out:
#             name                                             smiles
# 0    Abiraterone  [H][C@@]12CC=C(C3=CC=CN=C3)[C@@]1(C)CC[C@@]1([...
# 1     Acebutolol        CCCC(=O)NC1=CC(C(C)=O)=C(OCC(O)CNC(C)C)C=C1
# 2  Acenocoumarol  CC(=O)CC(C1=CC=C(C=C1)[N+]([O-])=O)C1=C(O)C2=C...
# 3  Acetaminophen                              CC(=O)NC1=CC=C(O)C=C1
# 4  Acetazolamide                       CC(=O)NC1=NN=C(S1)S(N)(=O)=O

# %%
df_merge_db.count()
# Out:
# name      509
# smiles    509
# dtype: int64

# %%
df_to_write=df_merge_db[['smiles']]

# %%
obj={}
for x in df_merge_db['name']:
    obj[x]=1

# %%
# bortezomib
v=[[x,1] for x in df_to_write['smiles']]
cnt=0
for x,y in zip(df_db['name'],df_db['smiles']):
    if(x not in obj):
        v.append([y,0])
        cnt+=1;
    if(cnt==1000):
        break;

# %%
df_final_write=pd.DataFrame(v,columns=['smiles','interact'])
df_final_write
# Out:
#                                                  smiles  interact
# 0     [H][C@@]12CC=C(C3=CC=CN=C3)[C@@]1(C)CC[C@@]1([...         1
# 1           CCCC(=O)NC1=CC(C(C)=O)=C(OCC(O)CNC(C)C)C=C1         1
# 2     CC(=O)CC(C1=CC=C(C=C1)[N+]([O-])=O)C1=C(O)C2=C...         1
# 3                                 CC(=O)NC1=CC=C(O)C=C1         1
# 4                          CC(=O)NC1=NN=C(S1)S(N)(=O)=O         1
# ...                                                 ...       ...
# 1504  OC1=CC=C(C[C@]2(O)N=C3N(C=C(N=C3CC3=CC=CC=C3)C...         0
# 1505      ON1C2=CC=CN=C2C(=C1C1=CC=NC=C1)C1=CC=C(F)C=C1         0
# 1506  CC(=O)N[C@@H]1[C@@H](O)[C@@H](O)[C@@H](CO)O[C@...         0
# 1507  NS(=O)(=O)C1=CC=C(NC2=NC(=CC=N2)C2=CN=C3C=CC=C...         0
# 1508  O=C(N[C@@H](CC1=CC=CC=C1)C(=O)N[C@H](CCC1=CC=C...         0
#
# [1509 rows x 2 columns]

# %%
# Out:
# 0       [H][C@@]12CC=C(C3=CC=CN=C3)[C@@]1(C)CC[C@@]1([...
# 1             CCCC(=O)NC1=CC(C(C)=O)=C(OCC(O)CNC(C)C)C=C1
# 2       CC(=O)CC(C1=CC=C(C=C1)[N+]([O-])=O)C1=C(O)C2=C...
# 3                                   CC(=O)NC1=CC=C(O)C=C1
# 4                            CC(=O)NC1=NN=C(S1)S(N)(=O)=O
#                               ...
# 1504         CC(CN1C2=CC=CC=C2SC2=C1C=C(C=C2)C(C)=O)N(C)C
# 1505                  CCC1=C(C)NC2=C1C(=O)C(CN1CCOCC1)CC2
# 1506              CN1CCC2=C(C1)C(C1=CC=CC=C21)C1=CC=CC=C1
# 1507    CN(C)S(=O)(=O)C1=CC2=C(SC3=CC=CC=C3N2CCCN2CCC(...
# 1508    OCCN1CCN(CC\C=C2\C3=CC=CC=C3SC3=C2C=C(Cl)C=C3)CC1
# Name: smiles, Length: 1509, dtype: object

# %%
df_final_write.to_csv(paths+'borte_balanced.csv',index=False)
