# %%
# !pip install tensorflow==2.9

# %%
# !unzip "/content/drive/MyDrive/Phase II Project Work.zip"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dropout,Flatten,Dense,BatchNormalization,GlobalAvgPool2D,GaussianNoise,GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import tensorflow as tf
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=3072)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# import tensorflow as tf
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
test_set="/content/Phase II Project Work/Cancer_Data_Set/Breast_Cancer/testing"
train_set="/content/Phase II Project Work/Cancer_Data_Set/Breast_Cancer/training"

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_datagen= ImageDataGenerator(    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size = (224,224),
    batch_size = 128,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_set,
    target_size = (224,224),
    batch_size = 128,
    shuffle=True,
    class_mode = 'categorical')
# Out:
# Found 12000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
train_generator

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
es= EarlyStopping(monitor="accuracy",min_delta=0.01,patience=6,verbose=1,mode='auto')
mc=ModelCheckpoint(monitor="accuracy",filepath="/content/drive/MyDrive/Phase II Project Work/Cancer_Data_Set/Breast_Cancer/breast_cancer.h5",verbose=1,save_best_only=True,mode='auto')
cd=[es,mc]

# %%
import tensorflow as tf
base_model = tf.keras.applications.EfficientNetB2(weights='imagenet', input_shape=(224,224,3), include_top=False)
# base_model = tf.keras.applications.resnet50.ResNet50(weights='imagenet', input_shape=(224,224,3), include_top=False)
model = Sequential()
model.add(base_model)
model.add(GaussianNoise(0.25))
model.add(GlobalAveragePooling2D())
model.add(Dense(256,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.25))
model.add(Dropout(0.25))
model.add(Dense(2, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 7, 7, 1408)       7768569
#
#  gaussian_noise (GaussianNoi  (None, 7, 7, 1408)       0
#  se)
#
#  global_average_pooling2d (G  (None, 1408)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               360704
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  gaussian_noise_1 (GaussianN  (None, 256)              0
#  oise)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 8,130,811
# Trainable params: 8,062,724
# Non-trainable params: 68,087
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy','Precision','Recall'])

# %%
hs=model.fit(
    train_generator,
    epochs=20,
    verbose=1,
    steps_per_epoch=70,
    validation_data=test_generator,
    callbacks=cd
    )
# Out:
# Epoch 1/20
# 70/70 [==============================] - ETA: 0s - loss: 0.9314 - accuracy: 0.6536 - precision: 0.6536 - recall: 0.6536
# Epoch 1: accuracy improved from -inf to 0.65357, saving model to /content/drive/MyDrive/Phase II Project Work/Cancer_Data_Set/Breast_Cancer/breast_cancer.h5
# 70/70 [==============================] - 51s 463ms/step - loss: 0.9314 - accuracy: 0.6536 - precision: 0.6536 - recall: 0.6536 - val_loss: 0.7875 - val_accuracy: 0.5230 - val_precision: 0.5230 - val_recall: 0.5230
# Epoch 2/20
# 70/70 [==============================] - ETA: 0s - loss: 0.4958 - accuracy: 0.7821 - precision: 0.7821 - recall: 0.7821
# Epoch 2: accuracy improved from 0.65357 to 0.78214, saving model to /content/drive/MyDrive/Phase II Project Work/Cancer_Data_Set/Breast_Cancer/breast_cancer.h5
# 70/70 [==============================] - 32s 460ms/step - loss: 0.4958 - accuracy: 0.7821 - precision: 0.7821 - recall: 0.7821 - val_loss: 0.9946 - val_accuracy: 0.5910 - val_precision: 0.5910 - val_recall: 0.5910
# Epoch 3/20
# 70/70 [==============================] - ETA: 0s - loss: 0.4316 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250
# Epoch 3: accuracy improved from 0.78214 to 0.82500, saving model to /content/drive/MyDrive/Phase II Project Work/Cancer_Data_Set/Breast_Cancer/breast_cancer.h5
# 70/70 [==============================] - 32s 454ms/step - loss: 0.4316 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250 - val_loss: 0.8139 - val_accuracy: 0.7290 - val_precision: 0.7290 - val_recall: 0.7290
# Epoch 4/20
# 70/70 [==============================] - ETA: 0s - loss: 0.4460 - accuracy: 0.8161 - precision: 0.8161 - recall: 0.8161
# Epoch 4: accuracy did not improve from 0.82500
# 70/70 [==============================] - 30s 432ms/step - loss: 0.4460 - accuracy: 0.8161 - precision: 0.8161 - recall: 0.8161 - val_loss: 0.9537 - val_accuracy: 0.5340 - val_precision: 0.5340 - val_recall: 0.5340
# Epoch 5/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3998 - accuracy: 0.8411 - precision: 0.8411 - recall: 0.8411
# Epoch 5: accuracy improved from 0.82500 to 0.84107, saving model to /content/drive/MyDrive/Phase II Project Work/Cancer_Data_Set/Breast_Cancer/breast_cancer.h5
# 70/70 [==============================] - 33s 473ms/step - loss: 0.3998 - accuracy: 0.8411 - precision: 0.8411 - recall: 0.8411 - val_loss: 0.7922 - val_accuracy: 0.7120 - val_precision: 0.7120 - val_recall: 0.7120
# Epoch 6/20
# 70/70 [==============================] - ETA: 0s - loss: 0.4440 - accuracy: 0.8054 - precision: 0.8054 - recall: 0.8054
# Epoch 6: accuracy did not improve from 0.84107
# 70/70 [==============================] - 28s 405ms/step - loss: 0.4440 - accuracy: 0.8054 - precision: 0.8054 - recall: 0.8054 - val_loss: 1.0941 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000
# Epoch 7/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3915 - accuracy: 0.8214 - precision: 0.8214 - recall: 0.8214
# Epoch 7: accuracy did not improve from 0.84107
# 70/70 [==============================] - 30s 437ms/step - loss: 0.3915 - accuracy: 0.8214 - precision: 0.8214 - recall: 0.8214 - val_loss: 0.7428 - val_accuracy: 0.7650 - val_precision: 0.7650 - val_recall: 0.7650
# Epoch 8/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.8500 - precision: 0.8500 - recall: 0.8500
# Epoch 8: accuracy improved from 0.84107 to 0.85000, saving model to /content/drive/MyDrive/Phase II Project Work/Cancer_Data_Set/Breast_Cancer/breast_cancer.h5
# 70/70 [==============================] - 31s 438ms/step - loss: 0.3686 - accuracy: 0.8500 - precision: 0.8500 - recall: 0.8500 - val_loss: 0.8140 - val_accuracy: 0.7130 - val_precision: 0.7130 - val_recall: 0.7130
# Epoch 9/20
# 70/70 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250
# Epoch 9: accuracy did not improve from 0.85000
# 70/70 [==============================] - 31s 443ms/step - loss: 0.4246 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250 - val_loss: 1.2607 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000
# Epoch 10/20
# 70/70 [==============================] - ETA: 0s - loss: 0.3950 - accuracy: 0.8411 - precision: 0.8411 - recall: 0.8411
# Epoch 10: accuracy did not improve from 0.85000
# 70/70 [==============================] - 28s 405ms/step - loss: 0.3950 - accuracy: 0.8411 - precision: 0.8411 - recall: 0.8411 - val_loss: 0.5650 - val_accuracy: 0.7590 - val_precision: 0.7590 - val_recall: 0.7590
# Epoch 11/20
# 70/70 [==============================] - ETA: 0s - loss: 0.4086 - accuracy: 0.8357 - precision: 0.8357 - recall: 0.8357
# Epoch 11: accuracy did not improve from 0.85000
# 70/70 [==============================] - 31s 442ms/step - loss: 0.4086 - accuracy: 0.8357 - precision: 0.8357 - recall: 0.8357 - val_loss: 0.7273 - val_accuracy: 0.7810 - val_precision: 0.7810 - val_recall: 0.7810
# Epoch 11: early stopping

# %%
from matplotlib import pyplot as plt
plt.plot(hs.history['accuracy'])
plt.plot(hs.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
