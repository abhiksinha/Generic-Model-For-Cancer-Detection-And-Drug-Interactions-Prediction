# %%
# !pip install tensorflow==2.9

# %%
# !unzip "/content/drive/MyDrive/Lung_Cancer.zip"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dropout,Flatten,Dense,BatchNormalization,GlobalAvgPool2D,GaussianNoise,GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import tensorflow as tf
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=3072)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# import tensorflow as tf
# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.set_logical_device_configuration(
#         gpus[0],
#         [tf.config.LogicalDeviceConfiguration(memory_limit=1024)])
#     logical_gpus = tf.config.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
test_set="/content/Lung_Cancer/test"
train_set="/content/Lung_Cancer/train"

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1
)
test_datagen= ImageDataGenerator(    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size = (224,224),
    batch_size = 8,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_set,
    target_size = (224,224),
    batch_size = 8,
    shuffle=True,
    class_mode = 'categorical')
# Out:
# Found 5000 images belonging to 2 classes.
# Found 1056 images belonging to 2 classes.

# %%
train_generator

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
es= EarlyStopping(monitor="accuracy",min_delta=0.1,patience=5,verbose=1,mode='auto')
mc=ModelCheckpoint(monitor="accuracy",filepath="/content/drive/MyDrive/Phase II Project Work/LungCancer/lungmodel.h5",verbose=1,save_best_only=True,mode='auto')
cd=[es,mc]

# %%
import tensorflow as tf
base_model = tf.keras.applications.EfficientNetB2(weights='imagenet', input_shape=(224,224,3), include_top=False)
# base_model = tf.keras.applications.resnet50.ResNet50(weights='imagenet', input_shape=(224,224,3), include_top=False)
model = Sequential()
model.add(base_model)
model.add(GaussianNoise(0.25))
model.add(GlobalAveragePooling2D())
model.add(Dense(256,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.25))
model.add(Dropout(0.25))
model.add(Dense(2, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 7, 7, 1408)       7768569
#
#  gaussian_noise (GaussianNoi  (None, 7, 7, 1408)       0
#  se)
#
#  global_average_pooling2d (G  (None, 1408)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               360704
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  gaussian_noise_1 (GaussianN  (None, 256)              0
#  oise)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 8,130,811
# Trainable params: 8,062,724
# Non-trainable params: 68,087
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy','Precision','Recall'])

# %%
hs=model.fit(
    train_generator,
    epochs=20,
    verbose=1,
    steps_per_epoch=75,
    validation_data=test_generator,
    callbacks=cd
    )
# Out:
# Epoch 1/20
# 75/75 [==============================] - ETA: 0s - loss: 0.5610 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250
# Epoch 1: accuracy improved from -inf to 0.82500, saving model to /content/drive/MyDrive/Phase II Project Work/LungCancer/lungmodel.h5
# 75/75 [==============================] - 65s 637ms/step - loss: 0.5610 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250 - val_loss: 0.5695 - val_accuracy: 0.7112 - val_precision: 0.7112 - val_recall: 0.7112
# Epoch 2/20
# 75/75 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9100 - precision: 0.9100 - recall: 0.9100
# Epoch 2: accuracy improved from 0.82500 to 0.91000, saving model to /content/drive/MyDrive/Phase II Project Work/LungCancer/lungmodel.h5
# 75/75 [==============================] - 44s 593ms/step - loss: 0.2493 - accuracy: 0.9100 - precision: 0.9100 - recall: 0.9100 - val_loss: 0.0602 - val_accuracy: 0.9820 - val_precision: 0.9820 - val_recall: 0.9820
# Epoch 3/20
# 75/75 [==============================] - ETA: 0s - loss: 0.2277 - accuracy: 0.9283 - precision: 0.9283 - recall: 0.9283
# Epoch 3: accuracy improved from 0.91000 to 0.92833, saving model to /content/drive/MyDrive/Phase II Project Work/LungCancer/lungmodel.h5
# 75/75 [==============================] - 42s 564ms/step - loss: 0.2277 - accuracy: 0.9283 - precision: 0.9283 - recall: 0.9283 - val_loss: 0.0395 - val_accuracy: 0.9830 - val_precision: 0.9830 - val_recall: 0.9830
# Epoch 4/20
# 75/75 [==============================] - ETA: 0s - loss: 0.2087 - accuracy: 0.9300 - precision: 0.9300 - recall: 0.9300
# Epoch 4: accuracy improved from 0.92833 to 0.93000, saving model to /content/drive/MyDrive/Phase II Project Work/LungCancer/lungmodel.h5
# 75/75 [==============================] - 44s 591ms/step - loss: 0.2087 - accuracy: 0.9300 - precision: 0.9300 - recall: 0.9300 - val_loss: 0.1078 - val_accuracy: 0.9735 - val_precision: 0.9735 - val_recall: 0.9735
# Epoch 5/20
# 75/75 [==============================] - ETA: 0s - loss: 0.1109 - accuracy: 0.9683 - precision: 0.9683 - recall: 0.9683
# Epoch 5: accuracy improved from 0.93000 to 0.96833, saving model to /content/drive/MyDrive/Phase II Project Work/LungCancer/lungmodel.h5
# 75/75 [==============================] - 61s 821ms/step - loss: 0.1109 - accuracy: 0.9683 - precision: 0.9683 - recall: 0.9683 - val_loss: 0.0523 - val_accuracy: 0.9839 - val_precision: 0.9839 - val_recall: 0.9839
# Epoch 6/20
# 75/75 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9400 - precision: 0.9400 - recall: 0.9400
# Epoch 6: accuracy did not improve from 0.96833
# 75/75 [==============================] - 40s 533ms/step - loss: 0.1870 - accuracy: 0.9400 - precision: 0.9400 - recall: 0.9400 - val_loss: 0.0231 - val_accuracy: 0.9943 - val_precision: 0.9943 - val_recall: 0.9943
# Epoch 7/20
# 75/75 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9667 - precision: 0.9667 - recall: 0.9667
# Epoch 7: accuracy did not improve from 0.96833
# 75/75 [==============================] - 42s 568ms/step - loss: 0.0883 - accuracy: 0.9667 - precision: 0.9667 - recall: 0.9667 - val_loss: 1.3999 - val_accuracy: 0.8362 - val_precision: 0.8362 - val_recall: 0.8362
# Epoch 8/20
# 75/75 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700
# Epoch 8: accuracy improved from 0.96833 to 0.97000, saving model to /content/drive/MyDrive/Phase II Project Work/LungCancer/lungmodel.h5
# 75/75 [==============================] - 42s 569ms/step - loss: 0.1003 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - val_loss: 0.4320 - val_accuracy: 0.9280 - val_precision: 0.9280 - val_recall: 0.9280
# Epoch 8: early stopping

# %%
from matplotlib import pyplot as plt
plt.plot(hs.history['accuracy'])
plt.plot(hs.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
